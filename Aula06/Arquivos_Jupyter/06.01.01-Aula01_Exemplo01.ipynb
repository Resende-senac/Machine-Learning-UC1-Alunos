# %% [markdown]
# # 🧩 Aula 06 - Parte 01 - Exemplo 01

# %% [markdown]
# Este é um exemplo básico de **clusterização não supervisionada** usando o algoritmo **KMeans**, com dados criados artificialmente.

# %% [markdown]
# ### 1. Importações

# %% [markdown]
# - **`make_blobs`**: gera dados sintéticos (fictícios) para testes.
# - **`KMeans`**: algoritmo de clusterização usado para agrupar os dados.
# - **`matplotlib.pyplot`**: biblioteca para visualização de gráficos.

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. Geração dos Dados

# %% [markdown]
# - Cria **300 pontos** agrupados de duas dimensões em **4 centros** (clusters).
# - `X` são os dados (coordenadas x e y).
# - `y` são os rótulos reais dos grupos (não usados no aprendizado, pois é não supervisionado).

# %%
#X, y = make_blobs(n_samples=300, centers=4, random_state=42)
X, y = make_blobs(n_samples=300, centers=4, random_state=0)
print (f"\n\n Dados das Coordenadas : \n\n{X[:5]}")
# Out:
#  Dados das Coordenadas :
#
# [[ 0.02458305  2.96215652]
#  [-1.52392631  7.12573205]
#  [ 1.27450825  5.63017322]
#  [-0.86552334  7.80121774]
#  [ 0.74874067  2.55579434]]

# %% [markdown]
# 🎯 Finalidade da make_blobs()
#
# - A função `make_blobs()` do scikit-learn tem como finalidade gerar dados sintéticos (artificiais) com agrupamentos bem definidos, ou seja, pontos que se agrupam naturalmente em "bolhas" (blobs ). Esses dados são muito úteis para testar e entender algoritmos de clusterização , como o KMeans .
#
# 1. Criar dados de exemplo
#     - É ideal quando você ainda não tem dados reais ou quer **testar rapidamente um modelo**.
#
# 2. Teste de algoritmos de clusterização
#     - Como os grupos são claros e definidos, é fácil visualizar e verificar se o algoritmo está funcionando corretamente.
#
# 3. Visualização simples
#     - Os dados gerados normalmente têm 2 ou 3 dimensões, permitindo **visualizações** fáceis com **gráficos 2D ou 3D**.
#
#
# 🎯 Parâmetros principais:
#
# | Parâmetro | O que faz |
# |-----------|-----------|
# | `n_samples` | Número total de pontos (registros) a serem gerados. Ex: 300. |
# | `centers` | Número de grupos (clusters) desejados. Ex: 4. |
# | `random_state` | Semente para o gerador aleatório, garantindo reproducibilidade. |
# | `n_features` *(opcional)* | Número de características por ponto (padrão é 2). |
#
# 🎯 Saídas:
# - **`X`**: matriz de features (coordenadas dos pontos).
# - **`y`**: vetor com os rótulos reais dos grupos (só usado para validação/teste — não é necessário no aprendizado não supervisionado).
#
# 📊 Exemplo Visual
#
# Se você usar `make_blobs(centers=4)` e plotar os dados com matplotlib, verá algo assim:
#
# ```
#     🔵 ⬤
#    ⬤      ⬤
#        ⬤        ⬤
#      ⬤              🔴
#          ⬤   ⬤
#            ⬤
#       🟢          🟡
# ```

# %% [markdown]
# ### 3. Configuração e Treinamento do Modelo

# %% [markdown]
# ✅ O que é esse código?
#
# - Este é um exemplo de como usar o algoritmo **KMeans**, um método de **clusterização não supervisionada**, para **agrupar dados em 4 grupos**.

# %%
kmeans = KMeans(n_clusters=4, random_state=42)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %% [markdown]
# O primeiro comando  **cria** o modelo `KMeans`.
# - `n_clusters=4`: queremos dividir os dados em **4 grupos**.
# - `random_state=42`: garante que os resultados sejam **sempre os mesmos** quando o código for executado novamente (reprodutibilidade).
#
# No segundo comando o modelo **aprende** a estrutura dos dados e **encontra os 4 grupos**.
# - `X` é uma matriz com os dados (ex: coordenadas x e y).
# - O `.fit()` ajusta os centros dos clusters para melhor representar os grupos nos dados.

# %% [markdown]
# ### 4. Previsão dos Grupos

# %% [markdown]
# - Usa o modelo treinado para **prever** qual grupo cada ponto pertence.

# %%
labels = kmeans.predict(X)

# %% [markdown]
# ✅ O que ele faz?
#
# - Este comando usa o modelo **KMeans já treinado** para **prever a qual grupo (cluster)** cada ponto do conjunto `X` pertence.
#
#
# 🔍 Detalhando:
#
# - **`kmeans`**: é o modelo de clusterização que você treinou anteriormente com `.fit(X)`.
# - **`.predict(X)`**: pergunta ao modelo: *"Com base no que você aprendeu, qual é o grupo de cada ponto em X?"*
# - **`labels`**: é uma variável que vai armazenar as **respostas** — ou seja, qual **rótulo de cluster** foi atribuído a cada ponto.
#
# 📌 Exemplo prático:
#
# - Suponha que `X` tenha 300 pontos. Após rodar esse comando, `labels` será um array com 300 valores (cada um sendo 0, 1, 2 ou 3), indicando a qual dos **4 grupos** cada ponto foi atribuído.

# %% [markdown]
# ### 5. Visualização dos Resultados

# %% [markdown]
# ✅ O que ele faz?
#
# - Este código **cria um gráfico de dispersão (scatter plot)** para **visualizar os clusters** encontrados pelo algoritmo **KMeans**.

# %%
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis')
plt.title("Clusterização com KMeans")
plt.show()

# %% [markdown]
# - Mostra um gráfico com os pontos, **coloridos por grupo**.
# - Cada cor representa um cluster encontrado pelo KMeans.
#
#
# 🔍 Cria o gráfico de pontos
# ```python
# plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis')
# ```
# - `X[:, 0]`: pega a **primeira coluna** dos dados (coordenada x de cada ponto).
# - `X[:, 1]`: pega a **segunda coluna** dos dados (coordenada y de cada ponto).
# - `c=labels`: define a cor de cada ponto com base no **grupo (cluster)** atribuído pelo KMeans.
# - `cmap='viridis'`: define a **paleta de cores** usada no gráfico (neste caso, uma escala de verde).

# %% [markdown]
# ## ✅ Resumo Final

# %% [markdown]
# | Etapa | O que foi feito |
# |-------|------------------|
# | Dados | Gerados artificialmente com 4 grupos |
# | Modelo | Usado KMeans para identificar os grupos |
# | Treino | Feito com `.fit()` |
# | Previsão | Atribuído um grupo a cada ponto |
# | Visualização | Mostrado graficamente os clusters |
